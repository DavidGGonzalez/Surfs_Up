# %% [markdown]
# ### Call Dependencies
# URL to the Canvas page: https://courses.bootcampspot.com/courses/976/pages/9-dot-1-3-import-dependencies?module_item_id=358636

# %%
# NumPy and Pandas
import numpy as np
import pandas as pd

# MatplotLib
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# DateTime
import datetime as dt

# SQLAlchemy
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from sqlalchemy import inspect

# %% [markdown]
# #### FiveThirtyEight Style Sheet
# URL: https://matplotlib.org/stable/gallery/style_sheets/fivethirtyeight.html

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM
# ### ORM Object Relational Mapper
# URL: https://www.sqlalchemy.org/
#
# URL to Canvas page: https://courses.bootcampspot.com/courses/976/pages/9-dot-1-5-getting-started-with-sqlalchemy?module_item_id=358642

# %% [markdown]
# ### Database Setup

# %%
# Create Engine
engine = create_engine("sqlite:///hawaii.sqlite")

# reflect an existing database into a new model
Base = automap_base()

# reflect the tables
Base.prepare(engine, reflect=True)

# %%
# We can view all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# We can also use the inspect module, and get_tables_names() function
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['measurement', 'station']

# %%
# We can even iterate columns like this
columns = inspector.get_columns('measurement')
for column in columns:
    print(column)
# Out:
# {'name': 'id', 'type': INTEGER(), 'nullable': False, 'default': None, 'autoincrement': 'auto', 'primary_key': 1}
# {'name': 'station', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'date', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'prcp', 'type': FLOAT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'tobs', 'type': FLOAT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}

# %%
columns = inspector.get_columns('measurement')
for column in columns:
    print(column['name'])
# Out:
# id
# station
# date
# prcp
# tobs

# %%
# Execute a query
data = engine.execute("SELECT * FROM station")

for record in data:
    print(record)
# Out:
# (1, 'USC00519397', 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0)
# (2, 'USC00513117', 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6)
# (3, 'USC00514830', 'KUALOA RANCH HEADQUARTERS 886.9, HI US', 21.5213, -157.8374, 7.0)
# (4, 'USC00517948', 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9)
# (5, 'USC00518838', 'UPPER WAHIAWA 874.3, HI US', 21.4992, -158.0111, 306.6)
# (6, 'USC00519523', 'WAIMANALO EXPERIMENTAL FARM, HI US', 21.33556, -157.71139, 19.5)
# (7, 'USC00519281', 'WAIHEE 837.5, HI US', 21.45167, -157.84888999999998, 32.9)
# (8, 'USC00511918', 'HONOLULU OBSERVATORY 702.2, HI US', 21.3152, -157.9992, 0.9)
# (9, 'USC00516128', 'MANOA LYON ARBO 785.2, HI US', 21.3331, -157.8025, 152.4)

# %%
# Add query results to a DataFrame 
sta = engine.execute("SELECT * FROM station")
sta_df = pd.DataFrame(sta)
sta_df.head()

# Note: columns name were not specified correclty, find out why?
# Out:
#    0            1                                       2        3         4  \
# 0  1  USC00519397                    WAIKIKI 717.2, HI US  21.2716 -157.8168
# 1  2  USC00513117                    KANEOHE 838.1, HI US  21.4234 -157.8015
# 2  3  USC00514830  KUALOA RANCH HEADQUARTERS 886.9, HI US  21.5213 -157.8374
# 3  4  USC00517948                       PEARL CITY, HI US  21.3934 -157.9751
# 4  5  USC00518838              UPPER WAHIAWA 874.3, HI US  21.4992 -158.0111
#
#        5
# 0    3.0
# 1   14.6
# 2    7.0
# 3   11.9
# 4  306.6

# %%
# Instead use:
conn = engine.connect()
sta2_df = pd.read_sql("SELECT * FROM station", conn)
sta2_df.head()
# Out:
#    id      station                                    name  latitude  \
# 0   1  USC00519397                    WAIKIKI 717.2, HI US   21.2716
# 1   2  USC00513117                    KANEOHE 838.1, HI US   21.4234
# 2   3  USC00514830  KUALOA RANCH HEADQUARTERS 886.9, HI US   21.5213
# 3   4  USC00517948                       PEARL CITY, HI US   21.3934
# 4   5  USC00518838              UPPER WAHIAWA 874.3, HI US   21.4992
#
#    longitude  elevation
# 0  -157.8168        3.0
# 1  -157.8015       14.6
# 2  -157.8374        7.0
# 3  -157.9751       11.9
# 4  -158.0111      306.6

# %%
# Save references to each table
Measurement = Base.classes.measurement
Stations = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# # Exploratory Climate Analysis
# URL to Canvas page: https://courses.bootcampspot.com/courses/976/pages/9-dot-2-1-retrieve-the-precipitation-data?module_item_id=358646
#
# SQLAlchemy Query Object: https://docs.sqlalchemy.org/en/14/orm/query.html

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results. 
# Starting from the last data point in the database. 

# Calculate the date one year from the last date in data set.
prev_year = dt.date(2017, 8, 23) - dt.timedelta(days=365)

# Perform a query to retrieve the data and precipitation scores
results = []
results = session.query(Measurement.date, Measurement.prcp)
print(results.all())
# Out:
# [('2010-01-01', 0.08), ('2010-01-02', 0.0), ('2010-01-03', 0.0), ('2010-01-04', 0.0), ('2010-01-06', None), ('2010-01-07', 0.06), ('2010-01-08', 0.0), ('2010-01-09', 0.0), ('2010-01-10', 0.0), ('2010-01-11', 0.01), ('2010-01-12', 0.0), ('2010-01-14', 0.0), ('2010-01-15', 0.0), ('2010-01-16', 0.0), ('2010-01-17', 0.0), ('2010-01-18', 0.0), ('2010-01-19', 0.0), ('2010-01-20', 0.0), ('2010-01-21', 0.0), ('2010-01-22', 0.0), ('2010-01-23', 0.0), ('2010-01-24', 0.01), ('2010-01-25', 0.0), ('2010-01-26', 0.04), ('2010-01-27', 0.12), ('2010-01-28', 0.0), ('2010-01-30', None), ('2010-01-31', 0.03), ('2010-02-01', 0.01), ('2010-02-03', None), ('2010-02-04', 0.01), ('2010-02-05', 0.0), ('2010-02-06', 0.0), ('2010-02-07', 0.0), ('2010-02-08', 0.0), ('2010-02-09', 0.0), ('2010-02-11', 0.0), ('2010-02-12', 0.02), ('2010-02-13', 0.01), ('2010-02-14', 0.0), ('2010-02-15', 0.0), ('2010-02-16', 0.0), ('2010-02-17', 0.0), ('2010-02-19', None), ('2010-02-20', 0.03), ('2010-02-21', 0.0), ('2010-02-22', 
# ...

# %%
# Now filter by those with a datetime higher or equal to prev_year
results = session.query(Measurement.date, Measurement.prcp).filter(Measurement.date >= prev_year).all()
print(results)
# Out:
# [('2016-08-23', 0.0), ('2016-08-24', 0.08), ('2016-08-25', 0.08), ('2016-08-26', 0.0), ('2016-08-27', 0.0), ('2016-08-28', 0.01), ('2016-08-29', 0.0), ('2016-08-30', 0.0), ('2016-08-31', 0.13), ('2016-09-01', 0.0), ('2016-09-02', 0.0), ('2016-09-03', 0.0), ('2016-09-04', 0.03), ('2016-09-05', None), ('2016-09-06', None), ('2016-09-07', 0.05), ('2016-09-08', 0.0), ('2016-09-09', 0.03), ('2016-09-10', 0.0), ('2016-09-11', 0.05), ('2016-09-12', 0.0), ('2016-09-13', 0.02), ('2016-09-14', 1.32), ('2016-09-15', 0.42), ('2016-09-16', 0.06), ('2016-09-17', 0.05), ('2016-09-18', 0.0), ('2016-09-19', 0.0), ('2016-09-20', 0.0), ('2016-09-21', 0.0), ('2016-09-22', 0.02), ('2016-09-23', 0.0), ('2016-09-24', 0.0), ('2016-09-25', 0.0), ('2016-09-26', 0.06), ('2016-09-27', 0.02), ('2016-09-28', 0.0), ('2016-09-29', 0.0), ('2016-09-30', 0.0), ('2016-10-01', 0.0), ('2016-10-02', 0.0), ('2016-10-03', 0.0), ('2016-10-04', 0.0), ('2016-10-05', 0.0), ('2016-10-06', 0.0), ('2016-10-07', 0.0), ('2016-10-08'
# ...

# %% [markdown]
# URL to Canvas page: https://courses.bootcampspot.com/courses/976/pages/9-dot-2-2-save-query-results?module_item_id=358650

# %%
# Save the query results as a Pandas DataFrame and set the index to the date column
df = pd.DataFrame(results, columns=['date','precipitation'])
df.head()
# Out:
#          date  precipitation
# 0  2016-08-23           0.00
# 1  2016-08-24           0.08
# 2  2016-08-25           0.08
# 3  2016-08-26           0.00
# 4  2016-08-27           0.00

# %%
# Sort the dataframe by date
# Reminder: inplace=True will make the changes in the same DataFrame, otherwise it would create another DataFrame
df.set_index(df['date'], inplace=True)
df.head()
# Out:
#                   date  precipitation
# date
# 2016-08-23  2016-08-23           0.00
# 2016-08-24  2016-08-24           0.08
# 2016-08-25  2016-08-25           0.08
# 2016-08-26  2016-08-26           0.00
# 2016-08-27  2016-08-27           0.00

# %%
# Print with the index
print(df)
# Out:
#                   date  precipitation
# date
# 2016-08-23  2016-08-23           0.00
# 2016-08-24  2016-08-24           0.08
# 2016-08-25  2016-08-25           0.08
# 2016-08-26  2016-08-26           0.00
# 2016-08-27  2016-08-27           0.00
# ...                ...            ...
# 2017-08-19  2017-08-19           0.09
# 2017-08-20  2017-08-20            NaN
# 2017-08-21  2017-08-21           0.56
# 2017-08-22  2017-08-22           0.50
# 2017-08-23  2017-08-23           0.45
#
# [2230 rows x 2 columns]

# %%
# Print with the without index
print(df.to_string(index=False))
# Out:
#       date  precipitation
# 2016-08-23           0.00
# 2016-08-24           0.08
# 2016-08-25           0.08
# 2016-08-26           0.00
# 2016-08-27           0.00
# 2016-08-28           0.01
# 2016-08-29           0.00
# 2016-08-30           0.00
# 2016-08-31           0.13
# 2016-09-01           0.00
# 2016-09-02           0.00
# 2016-09-03           0.00
# 2016-09-04           0.03
# 2016-09-05            NaN
# 2016-09-06            NaN
# 2016-09-07           0.05
# 2016-09-08           0.00
# 2016-09-09           0.03
# 2016-09-10           0.00
# 2016-09-11           0.05
# 2016-09-12           0.00
# 2016-09-13           0.02
# 2016-09-14           1.32
# 2016-09-15           0.42
# 2016-09-16           0.06
# 2016-09-17           0.05
# 2016-09-18           0.00
# 2016-09-19           0.00
# 2016-09-20           0.00
# 2016-09-21           0.00
# 2016-09-22           0.02
# 2016-09-23           0.00
# 2016-09-24           0.00
# 2016-09-25           0.00
# ...

# %% [markdown]
# URL to Canvas page: https://courses.bootcampspot.com/courses/976/pages/9-dot-2-3-sort-the-dataframe?module_item_id=358653

# %%
# Sort Results
df = df.sort_index()
print(df.to_string(index=False))
# Out:
#       date  precipitation
# 2016-08-23           0.00
# 2016-08-23            NaN
# 2016-08-23           1.79
# 2016-08-23           0.05
# 2016-08-23           0.15
# 2016-08-23           0.70
# 2016-08-23           0.02
# 2016-08-24           0.08
# 2016-08-24           2.15
# 2016-08-24           2.28
# 2016-08-24            NaN
# 2016-08-24           1.45
# 2016-08-24           1.22
# 2016-08-24           2.15
# 2016-08-25           0.08
# 2016-08-25           0.00
# 2016-08-25           0.21
# 2016-08-25           0.06
# 2016-08-25           0.00
# 2016-08-25           0.11
# 2016-08-25           0.08
# 2016-08-26           0.03
# 2016-08-26           0.01
# 2016-08-26           0.00
# 2016-08-26           0.04
# 2016-08-26           0.02
# 2016-08-26           0.00
# 2016-08-27           0.18
# 2016-08-27           0.12
# 2016-08-27           0.00
# 2016-08-27           0.00
# 2016-08-27           0.02
# 2016-08-27            NaN
# 2016-08-28           0.60
# ...

# %% [markdown]
# URL to Canvas page: https://courses.bootcampspot.com/courses/976/pages/9-dot-2-4-plot-the-data?module_item_id=358655

# %%
# Use Pandas Plotting with Matplotlib to plot the data
# Simple sample, plt DataFrame content directly
df.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# URL to Canvas page: https://courses.bootcampspot.com/courses/976/pages/9-dot-2-5-generate-the-summary?module_item_id=358658
# ![StatisticsRewind.png](attachment:StatisticsRewind.png)

# %%
# Use Pandas to calcualte the summary statistics for the precipitation data
df.describe()
# Out:
#        precipitation
# count    2021.000000
# mean        0.177279
# std         0.461190
# min         0.000000
# 25%         0.000000
# 50%         0.020000
# 75%         0.130000
# max         6.700000

# %% [markdown]
# URL to Canvas page: https://courses.bootcampspot.com/courses/976/pages/9-dot-3-1-find-the-number-of-stations?module_item_id=358663
# ![all.png](attachment:all.png)

# %%
# How many stations are available in this dataset?
session.query(func.count(Stations.station)).all()
# Out:
# [(9,)]

# %% [markdown]
# URL to Canvas page: https://courses.bootcampspot.com/courses/976/pages/9-dot-3-2-determine-the-most-active-stations?module_item_id=358666

# %%
# What are the most active stations?
# List the stations and the counts in descending order.
session.query(Measurement.station, func.count(Measurement.station)).all()
# Out:
# [('USC00519397', 19550)]

# %%
# add group_by
session.query(Measurement.station, func.count(Measurement.station)).group_by(Measurement.station).all()
# Out:
# [('USC00511918', 1979),
#  ('USC00513117', 2709),
#  ('USC00514830', 2202),
#  ('USC00516128', 2612),
#  ('USC00517948', 1372),
#  ('USC00518838', 511),
#  ('USC00519281', 2772),
#  ('USC00519397', 2724),
#  ('USC00519523', 2669)]

# %%
# add order_by
session.query(Measurement.station, func.count(Measurement.station)).group_by(Measurement.station).order_by(func.count(Measurement.station).desc()).all()
# Out:
# [('USC00519281', 2772),
#  ('USC00519397', 2724),
#  ('USC00513117', 2709),
#  ('USC00519523', 2669),
#  ('USC00516128', 2612),
#  ('USC00514830', 2202),
#  ('USC00511918', 1979),
#  ('USC00517948', 1372),
#  ('USC00518838', 511)]

# %% [markdown]
# URL to Canvas page: https://courses.bootcampspot.com/courses/976/pages/9-dot-3-3-find-low-high-and-average-temperatures?module_item_id=358669

# %%
# Using the station id from the previous query, calculate the lowest temperature recorded, 
# highest temperature recorded, and average temperature most active station?

# Including all stations
session.query(func.min(Measurement.tobs), func.max(Measurement.tobs), func.avg(Measurement.tobs)).all()
# Out:
# [(53.0, 87.0, 73.09795396419437)]

# %%
# Filter by the most active station
session.query(func.min(Measurement.tobs), func.max(Measurement.tobs), func.avg(Measurement.tobs)).\
filter(Measurement.station == 'USC00519281').all()
# Out:
# [(54.0, 85.0, 71.66378066378067)]

# %%
# Using engine.execute
calculate = engine.execute('SELECT min(tobs), max(tobs), avg(tobs) FROM measurement WHERE station = "USC00519281"')
for record in calculate:
    print(record)
# Out:
# (54.0, 85.0, 71.66378066378067)

# %% [markdown]
# URL to Canvas page: https://courses.bootcampspot.com/courses/976/pages/9-dot-3-4-plot-the-highest-number-of-observations?module_item_id=358672

# %%
# Choose the station with the highest number of temperature observations.
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram
results = session.query(Measurement.tobs).filter(Measurement.station == 'USC00519281').filter(Measurement.date >= prev_year).all()
print(results)
# Out:
# [(77.0,), (77.0,), (80.0,), (80.0,), (75.0,), (73.0,), (78.0,), (77.0,), (78.0,), (80.0,), (80.0,), (78.0,), (78.0,), (78.0,), (73.0,), (74.0,), (80.0,), (79.0,), (77.0,), (80.0,), (76.0,), (79.0,), (75.0,), (79.0,), (78.0,), (79.0,), (78.0,), (78.0,), (76.0,), (74.0,), (77.0,), (78.0,), (79.0,), (79.0,), (77.0,), (80.0,), (78.0,), (78.0,), (78.0,), (77.0,), (79.0,), (79.0,), (79.0,), (79.0,), (75.0,), (76.0,), (73.0,), (72.0,), (71.0,), (77.0,), (79.0,), (78.0,), (79.0,), (77.0,), (79.0,), (77.0,), (78.0,), (78.0,), (78.0,), (78.0,), (77.0,), (74.0,), (75.0,), (76.0,), (73.0,), (76.0,), (74.0,), (77.0,), (76.0,), (76.0,), (74.0,), (75.0,), (75.0,), (75.0,), (75.0,), (71.0,), (63.0,), (70.0,), (68.0,), (67.0,), (77.0,), (74.0,), (77.0,), (76.0,), (76.0,), (75.0,), (76.0,), (75.0,), (73.0,), (75.0,), (73.0,), (75.0,), (74.0,), (75.0,), (74.0,), (75.0,), (73.0,), (75.0,), (73.0,), (73.0,), (74.0,), (70.0,), (72.0,), (70.0,), (67.0,), (67.0,), (69.0,), (70.0,), (68.0,), (69.0,), (69.0,)
# ...

# %%
# Now let's put the resulting dataset in a DataFrame
df = pd.DataFrame(results, columns=['tobs'])
# df.head()
print(df)
# Out:
#      tobs
# 0    77.0
# 1    77.0
# 2    80.0
# 3    80.0
# 4    75.0
# ..    ...
# 347  77.0
# 348  77.0
# 349  76.0
# 350  76.0
# 351  79.0
#
# [352 rows x 1 columns]

# %%
# Try plot
df.plot.hist(bins=12)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Using `plt.tight_layout()`, we can compress the x-axis labels so that they fit into the box holding our plot. For this particular graph, using this function won't change much, but it can be a lifesaver in situations where the x-axis doesn't fit into the box. It's a cosmetic change, but it makes a big difference when presenting professional work.

# %%
# Adjust bins to 5
df.plot.hist(bins=5)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Adjust bins to 20
df.plot.hist(bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# #### Analisys after adjusting bins
# The graph continue to show that temperature between 67 and 80 comprise most of the days in a year, obviously visualization would improve by adjusting the number of bins.

# %%
# Write a function called `calc_temps` that will accept start date and end date in the format '%Y-%m-%d' 
# and return the minimum, average, and maximum temperatures for that range of dates

# %% [markdown]
# # Challenge
# See __SurfsUp_Challenge.ipynb__ file
